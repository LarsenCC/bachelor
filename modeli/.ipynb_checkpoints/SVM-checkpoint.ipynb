# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
# authorize ...
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
downloaded = drive.CreateFile({'id':"1uFmJ00pFXVSP51RBSgSL13f3TvjnU3Jm"})
downloaded.GetContentFile('basic.csv')

# %% [markdown]
# # DATA

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math
# %matplotlib inline

# %%
df = pd.read_csv("basic.csv")
df.head()
# Out:
#    Unnamed: 0  Smoked  PhysInactive  ...  max_hr  vo2_l_min  vo2_ml_kg_min
# 0           0     0.0           1.0  ...   166.0    5.15300           47.8
# 1           1     0.0           1.0  ...   142.0    2.66304           45.6
# 2           2     0.0           0.0  ...   160.0    2.64000           29.0
# 3           4     1.0           1.0  ...   183.0    1.98000           22.9
# 4           5     0.0           0.0  ...   100.0    1.96800           27.8
#
# [5 rows x 31 columns]

# %%
from sklearn.svm import SVR
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate

# %% [markdown]
# # SVM max_hr

# %% [markdown]
# **RReliafF feature selection for max_hr**
#
# waist                     --> 0.008156
#
# bodyfat                   --> 0.013040
#
# fev1                      --> 0.014932
#
# fvc                       --> 0.016102
#
# weight Ib->kg             --> 0.021300
#
# BMI                       --> 0.022967
#
# height inch->cm           --> 0.026997
#
# resting_dbp               --> 0.033719
#
# resting_hr                --> 0.037176
#
# resting_sbp               --> 0.037925
#
# ageattest                 --> 0.045493

# %%
X = df[['waist', 'bodyfat', 'fev1', 'fvc', 'weight Ib->kg', 'BMI', 'height inch->cm', 'resting_dbp', 'resting_hr', 'resting_sbp', 'ageattest']]
y = df['max_hr']

# %%
X.head()
# Out:
#       waist   bodyfat      fev1  ...  resting_hr  resting_sbp  ageattest
# 0  0.333921  0.150895  0.320819  ...    0.318182     0.381818   0.322812
# 1  0.385551  0.300159  0.462457  ...    0.456250     0.380273   0.509326
# 2  0.385551  0.537049  0.462457  ...    0.456250     0.380273   0.609756
# 3  0.409780  0.259484  0.462457  ...    0.409091     0.345455   0.552367
# 4  0.385551  0.300159  0.121160  ...    0.318182     0.409091   0.853659
#
# [5 rows x 11 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=420)

# CV
svr = SVR(C=1.0, epsilon=0.2)
scores = cross_validate(svr, X_train, y_train, cv=5, 
                        scoring=('r2', 'neg_mean_squared_error'), return_train_score=True)
print(1 - scores['test_r2'])
# scores with 95% accuracy
print("RRMSE: %0.2f (+/- %0.2f)" % (1 - scores['test_r2'].mean(), scores['test_r2'].std() * 2))
# Out:
# [0.65862639 0.68002905 0.65018695 0.67793926 0.67691216]
# RRMSE: 0.67 (+/- 0.02)

# %%
regr = svr.fit(X_train, y_train)
# reg.coef_

# %%
y_pred = regr.predict(X_test)
RRMSE_max_hr = 1 - r2_score(y_test, y_pred)
print(RRMSE_max_hr)
# Out:
# 0.6384651693962635

# %%
# Scatter
sns.scatterplot(x = y_test, y = y_pred)

# %%
# BLAND-ALTMAN plot
sns.scatterplot(x=((y_pred + y_test) / 2), y=(y_test - y_pred))

# %% [markdown]
# # SVM vo2_l_min

# %% [markdown]
# **RReliafF feature selection for vo2_l_min**
#
# waist                     --> 0.009569
#
# bodyfat                   --> 0.014413
#
# fvc                       --> 0.018686
#
# Aritmia                   --> 0.020000
#
# BMI                       --> 0.021262
#
# fev1                      --> 0.021502
#
# weight Ib->kg             --> 0.022448
#
# resting_sbp               --> 0.032925
#
# height inch->cm           --> 0.034091
#
# resting_dbp               --> 0.035906
#
# resting_hr                --> 0.043977
#
# ageattest                 --> 0.045552

# %%
X = df[['waist', 'bodyfat', 'fvc', 'Aritmia', 'BMI', 'fev1', 'weight Ib->kg', 'height inch->cm', 'resting_dbp', 'resting_hr', 'resting_sbp', 'ageattest']]
y = df['vo2_l_min']

# %%
X.head()
# Out:
#       waist   bodyfat       fvc  ...  resting_hr  resting_sbp  ageattest
# 0  0.333921  0.150895  0.452555  ...    0.318182     0.381818   0.322812
# 1  0.385551  0.300159  0.416058  ...    0.456250     0.380273   0.509326
# 2  0.385551  0.537049  0.416058  ...    0.456250     0.380273   0.609756
# 3  0.409780  0.259484  0.416058  ...    0.409091     0.345455   0.552367
# 4  0.385551  0.300159  0.108029  ...    0.318182     0.409091   0.853659
#
# [5 rows x 12 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=420)

# CV
svr = SVR(C=1.0, epsilon=0.2)
scores = cross_validate(svr, X_train, y_train, cv=5, 
                        scoring=('r2', 'neg_mean_squared_error'), return_train_score=True)
print(1 - scores['test_r2'])
# scores with 95% accuracy
print("RRMSE: %0.2f (+/- %0.2f)" % (1 - scores['test_r2'].mean(), scores['test_r2'].std() * 2))
# Out:
# [0.97965955 0.99344826 0.95935748 0.97590356 0.98517035]
# RRMSE: 0.98 (+/- 0.02)

# %%
regr = svr.fit(X_train, y_train)
# reg.coef_

# %%
y_pred = regr.predict(X_test)
RRMSE_vo2_l_min = 1 - r2_score(y_test, y_pred)
print(RRMSE_vo2_l_min)
# Out:
# 0.966312782346322

# %%
# Scatter
sns.scatterplot(x = y_test, y = y_pred)

# %%
# BLAND-ALTMAN plot
sns.scatterplot(x=((y_pred + y_test) / 2), y=(y_test - y_pred))

# %% [markdown]
# # SVM vo2_ml_kg_min

# %% [markdown]
# **RReliafF feature selection for vo2_ml_kg_min**
#
# bodyfat                   --> 0.010269
#
# waist                     --> 0.013436
#
# fvc                       --> 0.017051
#
# fev1                      --> 0.017201
#
# weight Ib->kg             --> 0.025120
#
# BMI                       --> 0.027779
#
# height inch->cm           --> 0.032523
#
# resting_dbp               --> 0.036281
#
# resting_sbp               --> 0.041045
#
# ageattest                 --> 0.048465
#
# resting_hr                --> 0.050000

# %%
X = df[['waist', 'bodyfat', 'fvc', 'BMI', 'fev1', 'weight Ib->kg', 'height inch->cm', 'resting_dbp', 'resting_hr', 'resting_sbp', 'ageattest']]
y = df['vo2_ml_kg_min']

# %%
X.head()
# Out:
#       waist   bodyfat       fvc  ...  resting_hr  resting_sbp  ageattest
# 0  0.333921  0.150895  0.452555  ...    0.318182     0.381818   0.322812
# 1  0.385551  0.300159  0.416058  ...    0.456250     0.380273   0.509326
# 2  0.385551  0.537049  0.416058  ...    0.456250     0.380273   0.609756
# 3  0.409780  0.259484  0.416058  ...    0.409091     0.345455   0.552367
# 4  0.385551  0.300159  0.108029  ...    0.318182     0.409091   0.853659
#
# [5 rows x 11 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=420)

# CV
svr = SVR(C=1.0, epsilon=0.2)
scores = cross_validate(svr, X_train, y_train, cv=5, 
                        scoring=('r2', 'neg_mean_squared_error'), return_train_score=True)
print(1 - scores['test_r2'])
# scores with 95% accuracy
print("RRMSE: %0.2f (+/- %0.2f)" % (1 - scores['test_r2'].mean(), scores['test_r2'].std() * 2))
# Out:
# [0.97165523 0.98750418 0.96037259 0.9636786  0.96798759]
# RRMSE: 0.97 (+/- 0.02)

# %%
regr = svr.fit(X_train, y_train)
# reg.coef_

# %%
y_pred = regr.predict(X_test)
RRMSE_vo2_l_min = 1 - r2_score(y_test, y_pred)
print(RRMSE_vo2_l_min)
# Out:
# 0.9574449697748877

# %%
# Scatter
sns.scatterplot(x = y_test, y = y_pred)

# %%
# BLAND-ALTMAN plot
sns.scatterplot(x=((y_pred + y_test) / 2), y=(y_test - y_pred))
