# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math
# %matplotlib inline

from sklearn.linear_model import LinearRegression, Lasso
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_excel("data/baza_HR_v5.xlsx")
df.head()
# Out:
#    Numbers  ageattest  Gender  CR_Code  ethnic_code  height inch->cm  \
# 0     2570       42.0    Male      2.0          0.0           186.70
# 1        1       55.0  Female      2.0          4.0           159.99
# 2        2       62.0  Female      2.0          4.0           157.00
# 3        3       36.0    Male      3.0          NaN           172.72
# 4        4       58.0    Male      2.0          0.0           185.42
#
#    weight Ib->kg        BMI  waist    bodyfat  ...  W_step3_F_LT  \
# 0          84.81  24.330914  84.40  14.610523  ...   1950.034300
# 1          87.79  34.297256    NaN        NaN  ...   1577.914203
# 2          78.09  31.680798    NaN  44.800000  ...   1366.840800
# 3          73.75  24.721611    NaN        NaN  ...   1909.385940
# 4          80.82  23.507459  93.01  23.100000  ...   1579.747780
#
#    W_step3_F_GT  W_step3_F_EQ    W_step3_M    W_step3_F    W_step4_M  \
# 0   1938.650200     1998.9484  3011.289444  1938.650200  3342.531283
# 1   1558.897705     1756.5097  2120.430346  1558.897705  2120.430346
# 2   1364.580000     1482.1416  1840.014480  1364.580000  1840.014480
# 3   1899.408880     1945.0550  2790.245603  1899.408880  2790.245603
# 4   1578.323160     1599.7544  2427.721430  1578.323160  2427.721430
#
#      W_step4_F  Wasserman_vo2_l_kg_min  HRmax1  HRmax2
# 0  2151.901722               39.411995   178.0  178.96
# 1  1558.897705               17.757122   165.0  169.60
# 2  1364.580000               17.474453   158.0  164.56
# 3  1899.408880               37.833839   184.0  183.28
# 4  1578.323160               30.038622   162.0  167.44
#
# [5 rows x 102 columns]

# %%
get = ['VO2_Mayers', 'Wasserman_vo2_l_kg_min', 'HRmax1', 'HRmax2', 'max_hr','vo2_ml_kg_min']

# %%
baseline = df[get].dropna()

# %%
baseline.head()
# Out:
#    VO2_Mayers  Wasserman_vo2_l_kg_min  HRmax1  HRmax2  max_hr  vo2_ml_kg_min
# 0   39.774325               39.411995   178.0  178.96  166.00           47.8
# 1   20.169964               17.757122   165.0  169.60  142.00           45.6
# 2   20.155835               17.474453   158.0  164.56  160.00           29.0
# 3   45.210978               37.833839   184.0  183.28  166.73           13.2
# 4   34.651472               30.038622   162.0  167.44  183.00           22.9

# %% [markdown]
# # HRmax

# %% [markdown]
# # VO2max

# %%
y = baseline['vo2_ml_kg_min']
y_pred = baseline['VO2_Mayers']
RRMSE = 1 - r2_score(y, y_pred)
print("------------------------------")
print("OVERALL RRMSE")
print(RRMSE)
print("OVERALL RMSE")
print(math.sqrt(mean_squared_error(y, y_pred)))
# BLAND-ALTMAN plot
sns.scatterplot(x=((y + y_pred) / 2), y=(y - y_pred))
# Out:
# ------------------------------
# OVERALL RRMSE
# 1.4480194819437227
# OVERALL RMSE
# 12.944396619722406
